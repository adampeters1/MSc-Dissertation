# %%
import pandas as pd
from textblob import TextBlob

# %%
def analyze_sentiment(text):
    analysis = TextBlob(text)

    # Define a threshold for positive and negative sentiment
    if analysis.sentiment.polarity > 0.1:
        return 'positive'
    elif analysis.sentiment.polarity < -0.1:
        return 'negative'
    else:
        return 'neutral'

# %%
from google.colab import drive
drive.mount('/content/gdrive')

df = pd.read_csv("gdrive/My Drive/Dissertation Complete/college_confidential_NE.csv")

df.head()
df.shape
# Out:
# Mounted at /content/gdrive
# (444622, 2)

# %%
df['textblob_predicted_sentiment'] = df['content'].apply(analyze_sentiment)

df = df.sort_values(by='textblob_predicted_sentiment', ascending=False)
df.head(50)

from google.colab import drive

drive.mount('/content/gdrive')
path = '/content/gdrive/My Drive/Dissertation Complete/textblob_results.csv'

with open(path, 'w') as f:
  df.to_csv(f, encoding='utf-8', index=False, header=True)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv("gdrive/My Drive/Dissertation Complete/textblob_results.csv")

df.head()
# Out:
#                                              content  university  \
# 0  Hey, Thanks so much for the response! I actual...         UNC
# 1  I thought school was to learn, get involved, a...         UVA
# 2  Seems kind of late for you to be so utterly un...  Georgetown
# 3  Do you have outside scholarship money? You sho...  Georgetown
# 4  Cal engineering is probably the best choice as...  Georgetown
#
#   textblob_predicted_sentiment
# 0                     positive
# 1                     positive
# 2                     positive
# 3                     positive
# 4                     positive
